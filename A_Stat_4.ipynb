# %% [markdown]
# Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.
# Probability Mass Function (PMF):
#
# The PMF is a function that gives the probability that a discrete random variable is exactly equal to some value. It is used for discrete random variables.
# Example: Consider a fair six-sided die. The PMF for each outcome
# 𝑋
# X (1, 2, 3, 4, 5, 6) is 1/6
#
# Probability Density Function (PDF):
#
# The PDF is a function that describes the likelihood of a continuous random variable to take on a particular value. It is used for continuous random variables. The area under the curve of a PDF over an interval represents the probability that the variable falls within that interval.
#
# Q2.Cumulative Density Function (CDF):
#
# The CDF of a random variable
# 𝑋
# X is a function that gives the probability that
# 𝑋
# X will take a value less than or equal to
# 𝑥
# x. For a continuous random variable, it is the integral of the PDF. For a discrete random variable, it is the sum of the PMF.
# Why CDF is used:
#
# The CDF is used to determine the probability that a random variable falls within a certain range. It is also useful for finding percentiles and quantiles.
#
# Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.
# Examples of Situations:
#
# Heights of individuals in a population.
# Measurement errors in scientific experiments.
# IQ scores.
# Daily stock market returns.
# Parameters and Shape:
#
# Mean (
# 𝜇
# μ): Determines the center of the distribution. Shifting the mean shifts the distribution left or right.
# Standard Deviation (
# 𝜎
# σ): Determines the spread of the distribution. A larger
# 𝜎
# σ results in a wider and flatter distribution, while a smaller
# 𝜎
# σ results in a narrower and taller distribution.
# Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution.
# Importance of Normal Distribution:
#
# The normal distribution is important because many natural phenomena tend to follow it. It also has desirable mathematical properties that make it useful in statistical analysis and inferential statistics. Many statistical tests assume normality due to the central limit theorem, which states that the distribution of sample means approximates a normal distribution as the sample size increases.
# Real-life Examples:
#
# Heights of people.
# Blood pressure readings.
# Exam scores.
# Measurement errors in physical and engineering processes.
# Q5: What is Bernoulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial Distribution?
# The Bernoulli distribution is a discrete distribution with only two possible outcomes: success (with probability 𝑝
#  and failure (with probability 1−p). It models a single trial of a binary experiment.
# Example: Flipping a fair coin (success = heads, failure = tails).
# Difference:
#
# Bernoulli Distribution: Models a single trial with two possible outcomes.
# Binomial Distribution: Models the number of successes in n independent Bernoulli trials, each with the same probability of success p.
#
# Q9: What is the Central Limit Theorem? State the significance of the Central Limit Theorem.
# Central Limit Theorem (CLT):
#
# The CLT states that the distribution of the sample means approximates a normal distribution as the sample size becomes large, regardless of the population's distribution, provided the samples are independent and identically distributed.
# Significance:
#
# It allows for the use of normal distribution techniques in inferential statistics.
# It justifies the use of the normal distribution in hypothesis testing and confidence interval estimation.
# Q10: State the assumptions of the Central Limit Theorem.
# The sample size should be sufficiently large (usually
#
# n>30 is considered adequate).
# Samples should be independent of each other.
# The data should be identically distributed (i.e., drawn from the same population distribution).
